# %%
import pandas as pd

# %%
content= pd.read_csv('C:/Users/tusha/Documents/Data Science Course/python project/Accenture iNTERNSHIP/Content.csv')

# %%
content.head(10)
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
# 5           5  cf1e8c1a-23eb-4426-9f58-002fb1b53e91
# 6           6  3f8590c7-6ab2-4973-805a-90cdec355f05
# 7           7  e5490118-90d5-4572-ab1c-1fbc87b8d9ca
# 8           8  0bedca96-fb76-4287-a83c-17330ed39cce
# 9           9  b18cb63f-4c8e-44ee-a47f-541e95191d11
#
#                                 User ID   Type         Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %%
content.drop(axis=1, columns= ['Unnamed: 0','URL','User ID'],inplace=True)

# %%
content
# Out:
#                                Content ID   Type         Category
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2  photo         Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo   healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f  photo   healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6  photo       technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180  video             food
# ..                                    ...    ...              ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb  video  public speaking
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF       technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio         veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF          culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio       technology
#
# [1000 rows x 3 columns]

# %%
content.head()
# Out:
#                              Content ID   Type        Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo        Studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo  healthy eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  photo  healthy eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  photo      technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180  video            food

# %%
content.isnull().values.any()
# Out:
# False

# %%
content.rename(columns={'Type': 'Content Type'}, inplace=True)

# %%
content.head()
# Out:
#                              Content ID Content Type        Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo  healthy eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6        photo      technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180        video            food

# %%
content[content.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Content ID, Content Type, Category]
# Index: []

# %%
content['Category'].unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', '"culture"', 'Fitness', '"studying"',
#        'Veganism', '"animals"', 'Travel', '"soccer"', 'Education',
#        '"dogs"', 'Technology', 'Soccer', '"tennis"', 'Culture', '"food"',
#        'Food', '"technology"', 'Healthy Eating', '"cooking"', 'Science',
#        '"public speaking"', '"veganism"', 'Public Speaking', '"science"'],
#       dtype=object)

# %%
content['Category']=content['Category'].str.lower()

# %%
content[content['Category'].str.startswith('"')]
# Out:
#                                Content ID Content Type           Category
# 50   2d949603-6676-4402-900b-2c2c78315ea0        audio          "culture"
# 100  c8b044a9-8427-4b41-bc61-7b549ab1626c        photo         "studying"
# 150  5651450a-d330-46e6-bac9-c7c7e7defaf2        photo          "animals"
# 200  48a824bf-e495-4333-8acf-c800947ec2cd        audio           "soccer"
# 250  78461336-26e2-4d0c-ab9a-fefbe419a8dd        video             "dogs"
# 300  693b5f91-52b1-4464-916c-91adccbec996        photo          "culture"
# 400  93081b1a-4446-438a-a0d7-fbcedc3c992d          GIF           "soccer"
# 450  bde82663-7be3-453d-afc2-539202df27c3        video           "tennis"
# 500  6380e982-07ac-4d21-bd23-cec0bcfa1ff9        photo           "soccer"
# 550  e4487829-621f-4265-8665-42a4c0610745        audio             "food"
# 600  0fbdd670-a266-4805-9bbc-c5ad73cf97b3        photo       "technology"
# 650  9c8be342-6cff-4d80-bf94-fd0fd8ccd845        video             "dogs"
# ...

# %%
content['Category'].replace('"', '',regex=True,inplace=True)

# %%
content['Category'].unique()
# Out:
# array(['studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'veganism', 'animals', 'culture'],
#       dtype=object)

# %%
content.head()
# Out:
#                              Content ID Content Type        Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo  healthy eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6        photo      technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180        video            food

# %%
reaction= pd.read_csv('C:/Users/tusha/Documents/Data Science Course/python project/Accenture iNTERNSHIP/Reactions.csv')

# %%
reaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 998.3+ KB

# %%
reaction.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
reaction.isnull().values.any()
# Out:
# True

# %%
reaction.drop(columns=['Unnamed: 0', 'User ID'],inplace=True)

# %%
reaction.head()
# Out:
#                              Content ID     Type             Datetime
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2      NaN  2021-04-22 15:17:15
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust  2020-11-07 09:43:50
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  dislike  2021-06-17 12:22:51
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2   scared  2021-04-18 05:13:58
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust  2021-01-06 19:13:01

# %%
reaction[reaction.isnull().any(axis=1)]
# Out:
#                                  Content ID Type             Datetime
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2  NaN  2021-04-22 15:17:15
# 46     9f737e0a-3cdd-4d29-9d24-753f4e3be810  NaN  2020-12-04 20:00:31
# 62     230c4e4d-70c3-461d-b42c-ec09396efb3f  NaN  2021-03-19 08:19:38
# 94     356fff80-da4d-4785-9f43-bc1261031dc6  NaN  2020-08-28 23:43:55
# 102    01ab84dd-6364-4236-abbb-3f237db77180  NaN  2021-02-08 21:55:56
# ...                                     ...  ...                  ...
# 25445  b4cef9ef-627b-41d7-a051-5961b0204ebb  NaN  2020-11-30 15:26:32
# 25449  7a79f4e4-3b7d-44dc-bdef-bc990740252c  NaN  2021-04-04 19:39:36
# 25454  435007a5-6261-4d8b-b0a4-55fdc189754b  NaN  2021-01-04 20:28:29
# 25499  4e4c9690-c013-4ee7-9e66-943d8cbd27b7  NaN  2021-05-25 18:05:31
# 25540  75d6b589-7fae-4a6d-b0d0-752845150e56  NaN  2021-04-25 05:09:20
#
# [980 rows x 3 columns]

# %%
reaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content ID  25553 non-null  object
#  1   Type        24573 non-null  object
#  2   Datetime    25553 non-null  object
# dtypes: object(3)
# memory usage: 599.0+ KB

# %%
reaction.dropna(inplace=True)

# %%
reaction[reaction.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Content ID, Type, Datetime]
# Index: []

# %%
reaction.rename(columns={'Type': 'Reaction Type'}, inplace=True)

# %%
reaction.head()
# Out:
#                              Content ID Reaction Type             Datetime
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  2021-04-18 05:13:58
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  2020-08-23 12:25:58

# %%
reaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24573 entries, 1 to 25552
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     24573 non-null  object
#  1   Reaction Type  24573 non-null  object
#  2   Datetime       24573 non-null  object
# dtypes: object(3)
# memory usage: 767.9+ KB

# %%
reaction
# Out:
#                                  Content ID Reaction Type             Datetime
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  2021-04-18 05:13:58
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  2020-08-23 12:25:58
# ...                                     ...           ...                  ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike  2020-06-27 09:46:48
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued  2021-02-16 17:17:02
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested  2020-09-12 03:54:58
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried  2020-11-04 20:08:31
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish  2021-01-04 04:55:11
#
# ...

# %%
reaction_types= pd.read_csv('C:/Users/tusha/Documents/Data Science Course/python project/Accenture iNTERNSHIP/ReactionTypes.csv')

# %%
reaction_types.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
reaction_types.isnull().values.any()
# Out:
# False

# %%
reaction_types.rename(columns={'Type':'Reaction Type'},inplace=True)

# %%
reaction_types.drop(columns='Unnamed: 0',inplace=True)

# %%
reaction_types
# Out:
#    Reaction Type Sentiment  Score
# 0          heart  positive     60
# 1           want  positive     70
# 2        disgust  negative      0
# 3           hate  negative      5
# 4     interested  positive     30
# 5    indifferent   neutral     20
# 6           love  positive     65
# 7     super love  positive     75
# 8        cherish  positive     70
# 9          adore  positive     72
# 10          like  positive     50
# 11       dislike  negative     10
# 12     intrigued  positive     45
# 13       peeking   neutral     35
# 14        scared  negative     15
# 15       worried  negative     12

# %%
reaction_types.head()
# Out:
#   Reaction Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30

# %%
'''with pd.ExcelWriter('final_data.xlsx') as writer:
    content.to_excel(writer, sheet_name='content', index=False)
    reaction.to_excel(writer, sheet_name='reaction', index=False)
    reaction_types.to_excel(writer,sheet_name= "reaction_type",index=False)'''
# Out:
# 'with pd.ExcelWriter(\'final_data.xlsx\') as writer:\n    content.to_excel(writer, sheet_name=\'content\', index=False)\n    reaction.to_excel(writer, sheet_name=\'reaction\', index=False)\n    reaction_types.to_excel(writer,sheet_name= "reaction_type",index=False)'

# %%
df1 = pd.merge(reaction,content,on= 'Content ID',how= 'left')

# %%
df1.head()
# Out:
#                              Content ID Reaction Type             Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  2021-04-18 05:13:58
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  2020-08-23 12:25:58
#
#   Content Type  Category
# 0        photo  studying
# 1        photo  studying
# 2        photo  studying
# 3        photo  studying
# 4        photo  studying

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24573 entries, 0 to 24572
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     24573 non-null  object
#  1   Reaction Type  24573 non-null  object
#  2   Datetime       24573 non-null  object
#  3   Content Type   24573 non-null  object
#  4   Category       24573 non-null  object
# dtypes: object(5)
# memory usage: 1.1+ MB

# %%
final_dataset=pd.merge(df1,reaction_types, on='Reaction Type', how= 'left')

# %%
final_dataset.head()
# Out:
#                              Content ID Reaction Type             Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  2021-04-18 05:13:58
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  2020-08-23 12:25:58
#
#   Content Type  Category Sentiment  Score
# 0        photo  studying  negative      0
# 1        photo  studying  negative     10
# 2        photo  studying  negative     15
# 3        photo  studying  negative      0
# 4        photo  studying  positive     30

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24573 entries, 0 to 24572
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     24573 non-null  object
#  1   Reaction Type  24573 non-null  object
#  2   Datetime       24573 non-null  object
#  3   Content Type   24573 non-null  object
#  4   Category       24573 non-null  object
#  5   Sentiment      24573 non-null  object
#  6   Score          24573 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.5+ MB

# %%
df=final_dataset.reindex(columns=['Content ID','Content Type','Category','Datetime','Reaction Type','Sentiment','Score'])

# %%
df.head()
# Out:
#                              Content ID Content Type  Category  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
#
#               Datetime Reaction Type Sentiment  Score
# 0  2020-11-07 09:43:50       disgust  negative      0
# 1  2021-06-17 12:22:51       dislike  negative     10
# 2  2021-04-18 05:13:58        scared  negative     15
# 3  2021-01-06 19:13:01       disgust  negative      0
# 4  2020-08-23 12:25:58    interested  positive     30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24573 entries, 0 to 24572
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     24573 non-null  object
#  1   Content Type   24573 non-null  object
#  2   Category       24573 non-null  object
#  3   Datetime       24573 non-null  object
#  4   Reaction Type  24573 non-null  object
#  5   Sentiment      24573 non-null  object
#  6   Score          24573 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.5+ MB

# %%
#df.to_excel("Cleaned_DataSet.xlsx",index=False)

# %%
df_1=df.groupby(['Content ID','Content Type','Category']).sum().sort_values(by='Score', ascending=False).reset_index()

# %%
df_1.head()
# Out:
#                              Content ID Content Type    Category  Score
# 0  292051b5-b835-4a60-962a-bddf10da82bd        photo  technology   2273
# 1  697af362-e84b-4429-b4ea-4123c6ab44ba        video     science   2231
# 2  4dd4da35-453e-466d-95ca-b1a7710fac1f          GIF  technology   2223
# 3  cd568dd1-70cf-45d6-b495-10eebff8c920        photo        dogs   2222
# 4  31d142d9-4557-4613-bce5-cfe63cd0a3cf        photo      soccer   2164

# %%
category=df.groupby(['Category']).sum().sort_values(by='Score', ascending=False).reset_index()

# %%
category.head()
# Out:
#          Category  Score
# 0         animals  74965
# 1         science  71168
# 2  healthy eating  69339
# 3      technology  68738
# 4            food  66676

# %%
#category.to_excel("Category.xlsx",index=False)

# %%
'''with pd.ExcelWriter('final_data.xlsx') as writer:
    content.to_excel(writer, sheet_name='content', index=False)
    reaction.to_excel(writer, sheet_name='reaction', index=False)
    reaction_types.to_excel(writer,sheet_name= "reaction_type",index=False)
    df_final.to_excel(writer, sheet_name='final_set', index=False)'''
# Out:
# 'with pd.ExcelWriter(\'final_data.xlsx\') as writer:\n    content.to_excel(writer, sheet_name=\'content\', index=False)\n    reaction.to_excel(writer, sheet_name=\'reaction\', index=False)\n    reaction_types.to_excel(writer,sheet_name= "reaction_type",index=False)\n    df_final.to_excel(writer, sheet_name=\'final_set\', index=False)'

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(category['Score'], labels=category['Category'],autopct='%2.2f%%',radius=30)
plt.title('Categorical')
plt.axis('equal')
plt.show()
plt.gcf().set_dpi(150)

# save the plot as a PNG file

# %%
pwd
# Out:
# 'C:\\Users\\tusha\\Documents\\Data Science Course\\python project\\Accenture iNTERNSHIP'

# %%
df3=pd.read_excel('C:\\Users\\tusha\\Documents\\Data Science Course\\python project\\Accenture iNTERNSHIP\\Cleaned_DataSet.xlsx')

# %%
df3.head()
# Out:
#                              Content ID Content Type  Category  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
#
#               Datetime Reaction Type Sentiment  Score  Content_Month  \
# 0  2020-11-07 09:43:50       disgust  negative      0             11
# 1  2021-06-17 12:22:51       dislike  negative     10              6
# 2  2021-04-18 05:13:58        scared  negative     15              4
# 3  2021-01-06 19:13:01       disgust  negative      0              1
# 4  2020-08-23 12:25:58    interested  positive     30              8
#
#    Content_Year
# 0          2020
# 1          2021
# 2          2021
# 3          2021
# 4          2020

# %%
df3.Category.unique()
# Out:
# array(['studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'veganism', 'animals', 'culture'],
#       dtype=object)

# %%
df3.columns
# Out:
# Index(['Content ID', 'Content Type', 'Category', 'Datetime', 'Reaction Type',
#        'Sentiment', 'Score', 'Content_Month', 'Content_Year'],
#       dtype='object')

# %%
reaction_counts = df[['Category','Reaction Type','Score']]

# %%
reaction_counts.head()
# Out:
#    Category Reaction Type  Score
# 0  studying       disgust      0
# 1  studying       dislike     10
# 2  studying        scared     15
# 3  studying       disgust      0
# 4  studying    interested     30

# %%
df5=reaction_counts.groupby(['Category']).agg({'Score':'sum','Reaction Type':'count'})

# %%
df5.reset_index(inplace=True)

# %%
df5
# Out:
#            Category  Score  Reaction Type
# 0           animals  74965           1897
# 1           cooking  64756           1664
# 2           culture  66579           1676
# 3              dogs  52511           1338
# 4         education  57436           1433
# 5           fitness  55323           1395
# 6              food  66676           1699
# 7    healthy eating  69339           1717
# 8   public speaking  49264           1217
# 9           science  71168           1796
# 10           soccer  57783           1457
# 11         studying  54269           1363
# 12       technology  68738           1698
# 13           tennis  50339           1328
# 14           travel  64880           1647
# 15         veganism  49619           1248

# %%
#df5.drop('index',axis=1,inplace=True)

# %%
df5
# Out:
#            Category  Score  Reaction Type
# 0           animals  74965           1897
# 1           cooking  64756           1664
# 2           culture  66579           1676
# 3              dogs  52511           1338
# 4         education  57436           1433
# 5           fitness  55323           1395
# 6              food  66676           1699
# 7    healthy eating  69339           1717
# 8   public speaking  49264           1217
# 9           science  71168           1796
# 10           soccer  57783           1457
# 11         studying  54269           1363
# 12       technology  68738           1698
# 13           tennis  50339           1328
# 14           travel  64880           1647
# 15         veganism  49619           1248

# %%
df5.to_excel('popularity.xlsx',index=False)

# %%
df.head()
# Out:
#                              Content ID Content Type  Category  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
#
#               Datetime Reaction Type Sentiment  Score
# 0  2020-11-07 09:43:50       disgust  negative      0
# 1  2021-06-17 12:22:51       dislike  negative     10
# 2  2021-04-18 05:13:58        scared  negative     15
# 3  2021-01-06 19:13:01       disgust  negative      0
# 4  2020-08-23 12:25:58    interested  positive     30

# %%
import datetime

# %%
df['Content_Month']=df['Datetime'].str.split('-').str[1]

# %%
df['Content_Year']=df['Datetime'].str.split('-').str[0]

# %%
df['Content_Year']=df['Content_Year'].astype(int)
df['Content_Month']=df['Content_Month'].astype(int)

# %%
df.head()
# Out:
#                              Content ID Content Type  Category  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
#
#               Datetime Reaction Type Sentiment  Score  Content_Month  \
# 0  2020-11-07 09:43:50       disgust  negative      0             11
# 1  2021-06-17 12:22:51       dislike  negative     10              6
# 2  2021-04-18 05:13:58        scared  negative     15              4
# 3  2021-01-06 19:13:01       disgust  negative      0              1
# 4  2020-08-23 12:25:58    interested  positive     30              8
#
#    Content_Year
# 0          2020
# 1          2021
# 2          2021
# 3          2021
# 4          2020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24573 entries, 0 to 24572
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     24573 non-null  object
#  1   Content Type   24573 non-null  object
#  2   Category       24573 non-null  object
#  3   Datetime       24573 non-null  object
#  4   Reaction Type  24573 non-null  object
#  5   Sentiment      24573 non-null  object
#  6   Score          24573 non-null  int64
#  7   Content_Month  24573 non-null  int32
#  8   Content_Year   24573 non-null  int32
# dtypes: int32(2), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
month_=df.groupby('Content_Month').agg({'Content ID':'count'}).sort_values('Content ID',ascending=False).reset_index()

# %%
with pd.ExcelWriter('Cleaned_DataSet.xlsx') as writer:
    df.to_excel(writer,sheet_name='Final',index=False)
    df5.to_excel(writer, sheet_name='popularity', index=False)
    month_.to_excel(writer, sheet_name='month', index=False)

# %%
df.head(2)
# Out:
#                              Content ID Content Type  Category  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  studying
#
#               Datetime Reaction Type Sentiment  Score  Content_Month  \
# 0  2020-11-07 09:43:50       disgust  negative      0             11
# 1  2021-06-17 12:22:51       dislike  negative     10              6
#
#    Content_Year
# 0          2020
# 1          2021

# %%
df5
# Out:
#            Category  Score  Reaction Type
# 0           animals  74965           1897
# 1           cooking  64756           1664
# 2           culture  66579           1676
# 3              dogs  52511           1338
# 4         education  57436           1433
# 5           fitness  55323           1395
# 6              food  66676           1699
# 7    healthy eating  69339           1717
# 8   public speaking  49264           1217
# 9           science  71168           1796
# 10           soccer  57783           1457
# 11         studying  54269           1363
# 12       technology  68738           1698
# 13           tennis  50339           1328
# 14           travel  64880           1647
# 15         veganism  49619           1248

# %%
df5.rename(columns={'Reaction Type':'Total Reaction'},inplace=True)

# %%
df5
# Out:
#            Category  Score  Total Reaction
# 0           animals  74965            1897
# 1           cooking  64756            1664
# 2           culture  66579            1676
# 3              dogs  52511            1338
# 4         education  57436            1433
# 5           fitness  55323            1395
# 6              food  66676            1699
# 7    healthy eating  69339            1717
# 8   public speaking  49264            1217
# 9           science  71168            1796
# 10           soccer  57783            1457
# 11         studying  54269            1363
# 12       technology  68738            1698
# 13           tennis  50339            1328
# 14           travel  64880            1647
# 15         veganism  49619            1248

# %%
x = df5['Category']
z = df5['Score']
y= df5['Total Reaction']

plt.bar(x, y)
plt.title('Category with most reaction')
plt.xlabel('Category')
plt.ylabel('Total Reactions')
for i in range(len(y)):
    plt.text(i, y[i], str(y[i]), ha='center')
plt.xticks(rotation=90)

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8564\1166473640.py in <module>
# ----> 1 str(y(i))
#
# TypeError: 'Series' object is not callable

# %%
month_.head(2)
# Out:
#    Content_Month  Content ID
# 0              5        2138
# 1              1        2126

# %%
month_['months']=month_['Content_Month'].map({1:'January',2:'Febuary',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'Septembr',10:'October',11:'November',12:'December'})

# %%
month_.rename(columns={'Content ID': 'Total Posts'},inplace=True)

# %%
month_
# Out:
#     Content_Month  Total Posts    months
# 0               5         2138       May
# 1               1         2126   January
# 2               8         2114    August
# 3              12         2092  December
# 4               7         2070      July
# 5              10         2056   October
# 6              11         2034  November
# 7               9         2022  Septembr
# 8               6         2021      June
# 9               3         2012     March
# 10              4         1974     April
# 11              2         1914   Febuary

# %%
with pd.ExcelWriter('Cleaned_DataSet.xlsx') as writer:
    df.to_excel(writer,sheet_name='Final',index=False)
    df5.to_excel(writer, sheet_name='popularity', index=False)
    month_.to_excel(writer, sheet_name='month', index=False)

# %%
import seaborn as sns

# %%
x = month_['months']
y = month_['Total Posts']

plt.bar(x, y)
plt.title('Total Posts per Month')
plt.xlabel('Month')
plt.ylabel('Total Posts')
for i in range(len(x)):
    plt.text(i, y[i]+5, str(y[i]), ha='center')
plt.xticks(rotation=90)
plt.show()
